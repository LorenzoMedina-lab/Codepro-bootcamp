# %%
print('hola mundo')
# Out:
# hola mundo

# %%
# Orden de ejecucion:

fruta = "banana"
print(fruta)

cantidad de frutas = 4

# %%
# Datos variables
nombre = 'Lorenzo'
edad = 26
ciudad = 'Emboscada'
# 
print(nombre, edad, ciudad)
# Out:
# Lorenzo 26 Emboscada

# %%
#Datos Variable
cantidad_de_manzanas = 4
cantidad_de_naranjas = 6
cantidad_de_frutas = cantidad_de_manzanas+cantidad_de_naranjas
print('La cantidad total es',cantidad_de_frutas)
#Frutas Vendidas
frutas_vendidas = 5
frutas_restantes = cantidad_de_frutas-frutas_vendidas
print('El stock actual es de',frutas_restantes)
# Out:
# La cantidad total es 10
# El stock actual es de 5

# %%
#Variable Nombre
nombre = 'Maria'
apellido = 'Colman'
print(f'Buenas tardes, mi nombre es {nombre} y mi apellido es {apellido}')
# Out:
# Buenas tardes, mi nombre es Maria y mi apellido es Colman

# %%
#Solicitud de numero
primer_numero = int(input("ingresa el primer numero"))
segundo_numero = int(input("ingresa el segundo numero"))
print(primer_numero + segundo_numero)
# Out:
# 30

# %%
#Funcion Mate
def preparar_mate():
    print("Proceso iniciado porfavor aguarde un momento")
    print("Pedido completado")
#llamar a la funcion
preparar_mate()
preparar_mate()
preparar_mate()
# Out:
# Proceso iniciado porfavor aguarde un momento
# Pedido completado
# Proceso iniciado porfavor aguarde un momento
# Pedido completado
# Proceso iniciado porfavor aguarde un momento
# Pedido completado

# %%
#Funcion compra de aceite motor naftero
#Variable
tipo_de_aceite = input("Indique el tipo de aceite deseado")
cantidad_deseada = input("indique la cantidad de litros seada")
def mantenimiento(x,y):
    print(f"El cliente precisa el aceite {x} {y} litros")

mantenimiento(tipo_de_aceite,cantidad_deseada)
# Out:
# El cliente precisa el aceite 20w50 6 litros

# %%
#Tipo de remera
tamaño_remera = input("Indique el tamaño de remera deseado")
tipo_remera = input("indique el modelo deseado")
COLOR = input("indique el color deseado")

def compra_remera (tamaño_remera,tipo_remera,COLOR):
    print(f"Preparar remera tamaño {tamaño_remera} modelo {tipo_remera} en el color {COLOR}")

#llamar al proceso
compra_remera(tamaño_remera,tipo_remera,COLOR)
# Out:
# Preparar remera tamaño XXG modelo POLO en el color ROJO
