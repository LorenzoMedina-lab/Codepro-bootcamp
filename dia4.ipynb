# %%
print("hola mundo")
# Out:
# hola mundo

# %%
#Challenge

datos_usuario = {}

nombre = input("Ingresa tu nombre")
edad = int(input("Ingresa tu edad"))
sexo = input("Ingresa tu sexo")
telefono = int(input("Ingresa tu numero de telefono"))
correo = input("Ingresa tu correo electronico")
datos_usuario["Nombre"] = nombre
print(datos_usuario)
datos_usuario["Edad"] = edad
print(datos_usuario)
datos_usuario["Sexo"] = sexo
print(datos_usuario)
datos_usuario["telefono"] = telefono
print(datos_usuario)
datos_usuario["Correo"] = correo
print(datos_usuario)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 6
#       3 datos_usuario = {}
#       5 nombre = input("Ingresa tu nombre")
# ----> 6 edad = int(input("Ingresa tu edad"))
#       7 sexo = input("Ingresa tu sexo")
#       8 telefono = int(input("Ingresa tu numero de telefono"))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
#Challenge

datos_usuario = {}

nombre = "Lorenzo"
edad = 26
sexo = "Masculino"
telefono = 991341835
correo = "lorenzomedina821@gmail.com"
datos_usuario["Nombre"] = nombre
print(datos_usuario)
datos_usuario["Edad"] = edad
print(datos_usuario)
datos_usuario["Sexo"] = sexo
print(datos_usuario)
datos_usuario["telefono"] = telefono
print(datos_usuario)
datos_usuario["Correo"] = correo
print(datos_usuario)#

#Modificar datos
datos_usuario["Nombre"] = input("Ingresa el nombre deseado")
print(datos_usuario)

#Eliminar Datos
del datos_usuario["Sexo"] 
datos_usuario
# Out:
# {'Nombre': 'Lorenzo'}
# {'Nombre': 'Lorenzo', 'Edad': 26}
# {'Nombre': 'Lorenzo', 'Edad': 26, 'Sexo': 'Masculino'}
# {'Nombre': 'Lorenzo', 'Edad': 26, 'Sexo': 'Masculino', 'telefono': 991341835}
# {'Nombre': 'Lorenzo', 'Edad': 26, 'Sexo': 'Masculino', 'telefono': 991341835, 'Correo': 'lorenzomedina821@gmail.com'}
# {'Nombre': 'Miguel', 'Edad': 26, 'Sexo': 'Masculino', 'telefono': 991341835, 'Correo': 'lorenzomedina821@gmail.com'}
# {'Nombre': 'Miguel',
#  'Edad': 26,
#  'telefono': 991341835,
#  'Correo': 'lorenzomedina821@gmail.com'}

# %%
#challenge
agenda = {}
nombre = "Lorenzo"
telefono = 991341835

while True:
    accion = int(input"Que desea realizar, 1=Crear Contacto,2=Modificar")
    if accion == 1:
        contacto = input("Ingrese el nombre del contacto")
    elif accion ==2:
        print("Los valores a modificar son")
        print(agenda.items())
        contacto =input("Ingrese el nuevo nombre")

# %%
#Challenge
#Tipo de gato
class Gato:
    especie = "Felina"
    def __init__(self, nombre,color):
        self.nombre= nombre
        self.color= color

#Creando Gato1
gato1 = Gato("Miku","Negro")
print(f"Me llamo {gato1.nombre} y soy un gato de color {gato1.color}")
# Out:
# Me llamo Miku y soy un gato de color Negro

# %%
#Tipo de gato
class Gato:
    especie = "Felina"

    def __init__(self, nombre,color):

        self.nombre= nombre
        self.color= color
    def hablar(self,hablar):
        print(f"Cuando hablo digo {hablar}")

    def moverse(self,metros):
        print(f"Puedo moverme {metros}")
        
gato2 = Gato("Pelusa","gris")
gato2.hablar("Hola")
# Out:
# Cuando hablo digo Hola

# %% [markdown]
# Challenge 3🤺 - 15 min
# Definir una clase madre que herede a sus clases hijas dos atributos de instancia. Mostrar ambos atributos en pantalla desde los objetos de las clases hijas.
#
# Observación: Editar las clases hijas para que no se inicialicen.

# %%
class AnimalDomestico:
    tipo = "Domesticado Inofencivo"
    def __init__(self,nombre,color,):
        self.nombre = nombre
        self.color = color
    def dormir(self):
        print(f"Me paso la mayor parte del dia acostado")
class Perro(AnimalDomestico):

    def ladrar(self):
        print("Guau Guau")
class Gato(AnimalDomestico):
    def ronroneo(self):
        print(f"Cuando estoy seguro y a gusto ronroneo")

perro1 = Perro("Choco","Marron")
perro1.dormir()
gato1 = Gato("Pelusa","Marron")
gato1.dormir()
# Out:
# Me paso la mayor parte del dia acostado
# Me paso la mayor parte del dia acostado

# %% [markdown]
# Challenge 4 🤺 - 20 min
# Crear dos personajes de una historia que se representen a traves de clases. Ejemplo: Un hereo y un villano.
# Cada personaje debe tener poderes o acciones diferentes. Y deben presentarse en una frase.
#
# Ejemplo: Yo me llamo pepito y tengo super fuerza
# Ejemplo: Yo me llamo juanito y puedo volar

# %%
#Crear clase de personaje 
class Personaje:
    humano= "Persona"
    def __init__(self,nombre):
        self.nombre=nombre
class Heroe(Personaje):
    def vuelo(self):
        print(f"Puedo volar igualando la velocidad del sonido")
class Villano(Personaje):
    def ataque(self):
        print(f"Tengo la habilidad de controlar la materia")
heroe1 = Heroe("Masivo")
heroe1.nombre

villano1 = Villano("Troche")
villano1.nombre
# Out:
# 'Troche'
